# %% [markdown]
# ### 1. 변수와 자료형

# %%
name = "주승우"
age = "26"
my_age = 25
marriage = False

# %%
print(my_age)
# Out:
# 25

# %%
type(marriage)
# Out:
# bool

# %%
float(my_age)
type(my_age)
# Out:
# int

# %% [markdown]
# ### 2. 변수 네이밍 규칙
# - 영문, 숫자, 밑줄만 가능, 숫자로 시작 X
# - 예약어 X
# - 관례(PEP 8) : 변수는 소문자와 밑줄로 사용
#     - snake_case: 예) user_name
#     - CamelCase: 첫글자를 대문자로 예) UserInfo

# %% [markdown]
# ### 3. 숫자형
# - 정수
# - 실수
# - N진수

# %%
count = 42
pi = 3.14
octal = 0o17
hexa = 0xFF
big = 10_000_000

# %%
count * pi
# Out:
# 131.88

# %%
int(octal)
# Out:
# 15

# %%
int(hexa)
# Out:
# 255

# %%
# 연습 : 반지름 5인 원의 넓이를 구해서 출력해보세요 -> 반지름 변수, pi 변수 설정 후 곱하기 해서 출력해보세요
r = 5

Area = pi * r * r
print(Area)
# Out:
# 78.5

# %% [markdown]
# #### 3-2. 숫자형 연산
# - 더하기, 빼기, 곱하기, 나누기
# - 몫, 나머지
# - 제곱

# %%
사탕 = 13 # 현재 갖고 있는 사탕 - 연습을 위해 변수명을 이제부터 한글로
사람 = 4
과자 = 5

# %%
먹을것개수 = 사탕 + 과자
먹을것개수
# Out:
# 18

# %%
사탕 - 과자
# Out:
# 8

# %%
사탕 / 사람
# Out:
# 3.25

# %%
# 몫, 나머지
사탕 // 사람    # 13개의 사탕을 4명이 가지면, 3개씩(몫) 가지고 1개가 남는다
# Out:
# 3

# %%
사탕 % 사람 #나머지
# Out:
# 1

# %%
a=2
b=3

a**b #a를 b번 곱하기
# Out:
# 8

# %%
a = 5
b = 3
# 복합 연산자

# %%
a -= b
print(a)
# Out:
# 2

# %%
money = 50_000
money += 20_000
money -= 8500
money -= 5000
print(money)
# Out:
# 56500
