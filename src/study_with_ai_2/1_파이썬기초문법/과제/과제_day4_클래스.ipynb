# %% [markdown]
# # 과제 · 클래스
#
# 오늘 **가볍게** 배운 **클래스**를 연습합니다.
# 난이도 ⭐~⭐⭐⭐⭐. `# TODO`를 채워 실행하고 **예상 출력**과 비교하세요.

# %% [markdown]
# ## 문제 1. 간단한 클래스 · ⭐ 기초
#
# `사람`이라는 빈 클래스를 만들고, 객체를 하나 만들어 `이름` 속성에 `"유나"`를 넣고 출력하세요.

# %%
# TODO: class 사람: pass  -> 객체 만들고 .이름 = "유나"

class 사람:
    pass

yuna = 사람()
yuna.이름 = "유나"

print(yuna.이름)
# Out:
# 유나

# %% [markdown]
# ## 문제 2. __init__ 로 초기화 · ⭐⭐ 기본
#
# 만들 때 `이름`·`나이`를 받는 클래스 `학생`을 `__init__`으로 만들고, 객체의 이름·나이를 출력하세요.

# %%
# TODO: class 학생: def __init__(self, 이름, 나이): self.이름=... self.나이=...

class 학생:
    def __init__(self, 이름, 나이):
        self.name = 이름
        self.age = 나이

sw = 학생("주승우", 26)

print(sw.name)
print(sw.age)
# Out:
# 주승우
# 26

# %% [markdown]
# ## 문제 3. 메서드 추가 · ⭐⭐ 기본
#
# `학생` 클래스에 `소개` 메서드를 넣어 `"OO입니다. 25살이에요."`를 출력하게 하고, 호출하세요.

# %%
# TODO: class 학생 안에 def 소개(self): print(...)

class 학생:
    def __init__(self, 이름, 나이=25):
        self.name = 이름
        self.age = 나이

    def 소개(self):
        print(f"{self.name}입니다. {self.age}살이에요.")

ms = 학생("김민수")
ms.소개()
# Out:
# 김민수입니다. 25살이에요.

# %% [markdown]
# ## 도전. 책 클래스 · ⭐⭐⭐ 도전
#
# `제목`·`저자`를 받는 클래스 `책`을 만들고, `정보` 메서드로 `"제목 - 저자"`를 출력하게 하세요.

# %%
# TODO: class 책: __init__(self, 제목, 저자) / 정보 메서드

class 책:
    def __init__(self, 제목, 저자):
        self.title = 제목
        self.author = 저자

    def 정보(self):
        print(f"{self.title} - {self.author}")

book = 책("Odyssey", "Homer")
book.정보()
# Out:
# Odyssey - Homer

# %% [markdown]
# ## 제출 전 확인
#
# - 기초는 전부, 위로 갈수록 도전
# - 예상 출력과 결과가 같은지 확인
# - 막히면 AI엔 **힌트만**
