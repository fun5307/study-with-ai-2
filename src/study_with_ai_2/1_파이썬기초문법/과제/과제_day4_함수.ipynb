# %% [markdown]
# # 과제 · 함수
#
# **함수**로 풀어봅니다.
# 난이도: ⭐ 기초 → ⭐⭐ 기본 → ⭐⭐⭐ 응용 → ⭐⭐⭐⭐ 도전.
# `# TODO`를 채워 실행하고 **예상 출력**과 비교하세요.

# %% [markdown]
# ## 문제 1. 인사 함수 · ⭐ 기초
#
# `인사`라는 함수를 만들어 `"안녕하세요"`를 출력하고, 함수를 호출하세요.

# %%
# TODO: def 인사(): 로 함수를 만들고 호출

def 인사():
    print("안녕하세요")

인사()
# Out:
# 안녕하세요

# %% [markdown]
# ## 문제 2. 이름 넣어 인사 · ⭐ 기초
#
# 이름을 **매개변수**로 받아 `"OO님 안녕하세요"`를 출력하는 함수 `인사`를 만들고, `"유나"`로 호출하세요.

# %%
# TODO: def 인사(name): ... / 인사("유나")

def 인사(name):
    print(f"{name}님 안녕하세요")

인사("유나")
# Out:
# 유나님 안녕하세요

# %% [markdown]
# ## 문제 3. 두 수의 합 (return) · ⭐ 기초
#
# 두 수를 받아 **합을 return**하는 함수 `더하기`를 만들고, 3과 5의 합을 출력하세요.

# %%
# TODO: def 더하기(a, b): return a + b

def 더하기(a,b):
    return a+b

더하기(3,5)
# Out:
# 8

# %% [markdown]
# ## 문제 4. 직사각형 넓이 · ⭐⭐ 기본
#
# 가로·세로를 받아 **넓이를 return**하는 함수 `넓이`를 만들고, 가로 4·세로 3의 넓이를 출력하세요.

# %%
# TODO: def 넓이(가로, 세로): return 가로 * 세로

def 넓이(a,b):
    return a*b

넓이(4,3)
# Out:
# 12

# %% [markdown]
# ## 문제 5. 기본값 인자 · ⭐⭐ 기본
#
# 이름을 받되 **기본값을 `"손님"`**으로 하는 함수 `환영`을 만드세요. 인자 없이 호출과 `"민수"`로 호출을 각각 출력하세요.

# %%
# TODO: def 환영(name="손님"): ...

def 환영(name="손님"):
    print(f"{name}님 환영합니다")

환영()
환영("민수")
# Out:
# 손님님 환영합니다
# 민수님 환영합니다

# %% [markdown]
# ## 문제 6. 여러 값 반환 · ⭐⭐ 기본
#
# 숫자 리스트를 받아 **최솟값과 최댓값을 함께 return**하는 함수 `최소최대`를 만들고, 언패킹으로 받아 출력하세요.

# %%
# TODO: def 최소최대(nums): return min(nums), max(nums)
# 그리고 최소, 최대 = 최소최대([...]) 로 받기

def 최소최대(num_list):
    return min(num_list), max(num_list)

최소, 최대 = 최소최대([1,2,4,5,6,6,7,9])
print("최소:", 최소, "최대:", 최대)
# Out:
# 최소: 1 최대: 9

# %% [markdown]
# ## 문제 7. 개수가 정해지지 않은 인자 (*args) · ⭐⭐⭐ 응용
#
# **여러 개의 숫자**를 받아 합계를 return하는 함수 `합계`를 `*나이`(또는 `*args`)로 만드세요.

# %%
# TODO: def 합계(*nums): total 을 for 로 더해 return

def 합계(*args):
    return sum(args)

합계(1,2,3,3,4,5,6)
# Out:
# 24

# %% [markdown]
# ## 문제 8. 키워드 인자 (**kwargs) · ⭐⭐⭐ 응용
#
# 이름=값 형태의 정보를 여러 개 받아 한 줄씩 출력하는 함수 `정보출력`을 `**kwargs`로 만드세요.

# %%
# TODO: def 정보출력(**kwargs): for 키, 값 in kwargs.items(): 출력

def 정보출력(**kwargs):
    for key, value in kwargs.items():
        print(key, ":", value)

정보출력(이름="주승우", 나이=26, 지역="수원")
# Out:
# 이름 : 주승우
# 나이 : 26
# 지역 : 수원

# %% [markdown]
# ## 도전. 몫과 나머지 계산기 · ⭐⭐⭐⭐ 도전
#
# 두 수를 받아 **몫과 나머지를 함께 return**하는 함수 `나눗셈`을 만들고, 17을 5로 나눈 결과를 `"몫 3, 나머지 2"` 형태로 출력하세요.

# %%
# TODO: def 나눗셈(a, b): return a // b, a % b
# 몫, 나머지 = 나눗셈(17, 5) 로 받아 출력

def 나눗셈(a,b):
    몫 = a//b
    나머지 = a%b
    return f"몫 {몫}, 나머지 {나머지}"

나눗셈(17,5)
# Out:
# '몫 3, 나머지 2'

# %% [markdown]
# ## 제출 전 확인
#
# - 기초는 전부, 위로 갈수록 도전
# - 각 문제 **예상 출력과 결과가 같은지** 확인
# - 막히면 AI엔 **힌트만**(정답 통째로 X)
