# %% [markdown]
# # 과제 · Day 2 — 변수·연산·문자열·자료구조 (난이도별)
#
# 오늘 배운 것으로 풀어보세요: **변수·형변환·숫자연산 / 문자열 / 불·연산자 / 리스트·튜플·딕셔너리**.
#
# 난이도: ⭐ 기초(몸풀기, 7문제) → ⭐⭐ 기본(7문제) → ⭐⭐⭐ 응용(2문제) → ⭐⭐⭐⭐ 도전(2문제).
# **기초부터 하나씩** 채워 실행하고 **예상 출력**과 비교하세요. 쉬운 문제로 감을 잡은 뒤 위로 올라갑니다.

# %% [markdown]
# ## 문제 1. 두 수의 합 · ⭐ 기초
#
# 두 수 `a`, `b`의 **합**을 출력하세요.

# %%
a = 15
b = 27

# TODO: 합
합 = a+b
print("합:", 합)
# 예상: 합: 42
# Out:
# 합: 42

# %% [markdown]
# ## 문제 2. 나이 계산 · ⭐ 기초
#
# `태어난해`로 **올해(2026) 나이**를 구해 출력하세요.

# %%
태어난해 = 2005

# TODO: 나이 = 2026 - 태어난해
나이 = 2026 - 태어난해
print("나이:", 나이)
# 예상: 나이: 21
# Out:
# 나이: 21

# %% [markdown]
# ## 문제 3. 이름 붙이기 · ⭐ 기초
#
# 성 `first`와 이름 `last`를 붙여 **전체 이름**을 출력하세요.

# %%
first = "홍"
last = "길동"

# TODO: 문자열 더하기(+)
전체이름 = first+last
print("전체 이름:", 전체이름)
# 예상: 전체 이름: 홍길동
# Out:
# 전체 이름: 홍길동

# %% [markdown]
# ## 문제 4. 문자열 살펴보기 · ⭐ 기초
#
# `"python"`의 **글자 수**와 **대문자**를 출력하세요.

# %%
word = "python"

# TODO: len 과 upper()
print("길이:", len(word))
print("대문자:", word.upper())
# 예상: 길이 6 / 대문자 PYTHON
# Out:
# 길이: 6
# 대문자: PYTHON

# %% [markdown]
# ## 문제 5. 나눗셈 두 가지 · ⭐ 기초
#
# `10`을 `4`로 나눈 **실수 결과(/)**와 **정수 몫(//)**을 출력하세요.

# %%
# TODO: / 와 //
print("실수 나눗셈:", 10/4)
print("정수 몫:", 10//4)
# 예상: 실수 나눗셈 2.5 / 정수 몫 2
# Out:
# 실수 나눗셈: 2.5
# 정수 몫: 2

# %% [markdown]
# ## 문제 6. 리스트 꺼내기 · ⭐ 기초
#
# 색 리스트에서 **첫 번째**·**마지막** 색과 **개수**를 출력하세요.

# %%
colors = ["빨강", "초록", "파랑", "노랑"]

# TODO: [0], [-1], len
print("첫 색:", colors[0])
print("마지막 색:", colors[-1])
print("개수:", len(colors))
# 예상: 첫 색 빨강 / 마지막 색 노랑 / 개수 4
# Out:
# 첫 색: 빨강
# 마지막 색: 노랑
# 개수: 4

# %% [markdown]
# ## 문제 7. 딕셔너리 조회 · ⭐ 기초
#
# 가격표에서 **아메리카노 가격**을 찾아 출력하세요.

# %%
가격 = {"아메리카노": 4500, "라떼": 5000}

# TODO: 딕셔너리[키]
print("아메리카노:", 가격["아메리카노"], "원")
# 예상: 아메리카노 4500 원
# Out:
# 아메리카노: 4500 원

# %% [markdown]
# ## 문제 8. 사탕 나눠주기 · ⭐⭐ 기본
#
# 사탕 `27`개를 `4`명이 나눌 때 **몫**·**나머지**를 출력하세요.

# %%
사탕 = 27
사람 = 4

# TODO: // 와 %
몫 = 사탕//사람
나머지 = 사탕 % 사람
print(f"한 사람당 {몫}개씩, {나머지}개 남음")
# 예상: 한 사람당 6개씩, 3개 남음
# Out:
# 한 사람당 6개씩, 3개 남음

# %% [markdown]
# ## 문제 9. 초를 분·초로 · ⭐⭐ 기본
#
# `총초 = 125`를 **몇 분 몇 초**인지로 바꿔 출력하세요.

# %%
총초 = 125

# TODO: 분 = 총초 // 60, 초 = 총초 % 60
분 = 총초//60
초 = 총초 % 60
print(f"{분}분 {초}초")
# 예상: 2분 5초
# Out:
# 2분 5초

# %% [markdown]
# ## 문제 10. 날짜 잘라 읽기 · ⭐⭐ 기본
#
# `"20260831"`에서 **연(앞 4)·월(4~6)·일(뒤 2)**을 슬라이싱으로 뽑아 출력하세요.

# %%
ymd = "20260831"

# TODO: 슬라이싱 [:4], [4:6], [6:]
연 = ymd[:4]
월 = ymd[4:6]
일 = ymd[-2:]
print(연, 월, 일)
# 예상: 2026 08 31
# Out:
# 2026 08 31

# %% [markdown]
# ## 문제 11. 전화번호 정리 · ⭐⭐ 기본
#
# `"010.1234.5678"`의 `.`을 `-`로 바꿔 출력하세요.

# %%
phone = "010.1234.5678"

# TODO: replace
결과 = phone.replace(".", "-")
print(결과)
# 예상: 010-1234-5678
# Out:
# 010-1234-5678

# %% [markdown]
# ## 문제 12. 주민번호 파싱 · ⭐⭐ 기본
#
# 주민번호에서 **생년(앞 2)**·**성별 숫자(인덱스 7)**를 뽑고, 성별 숫자 % 2 를 출력하세요.

# %%
id_number = "020315-3011234"

# TODO: [:2] 와 [7]
생년 = id_number[:2]
성별숫자 = id_number[7]
print("생년:", 생년, "/ 성별숫자:", 성별숫자, "/ 나머지:", int(성별숫자) % 2)
# 예상: 생년 02 / 성별숫자 3 / 나머지 1
# Out:
# 생년: 02 / 성별숫자: 3 / 나머지: 1

# %% [markdown]
# ## 문제 13. 장바구니 담기 · ⭐⭐ 기본
#
# 장바구니에 `"계란"`·`"사과"`를 추가하고, 전체와 **개수**를 출력하세요.

# %%
cart = ["우유", "빵"]

# TODO: append 두 번
cart.append("계란")
cart.append("사과")

print(cart)
print("개수:", len(cart))
# 예상: ['우유', '빵', '계란', '사과'] / 개수 4
# Out:
# ['우유', '빵', '계란', '사과']
# 개수: 4

# %% [markdown]
# ## 문제 14. 지원 자격 판별식 · ⭐⭐ 기본
#
# `나이` 20 이상 **그리고** `경력` 2 이상이면 True인 식을 `지원가능`에 담아 출력하세요. (`if` 없이)

# %%
나이 = 25
경력 = 3

# TODO: 비교·논리(and)
지원가능 = 나이 >= 20 and 경력 >= 2
print("지원 가능?", 지원가능)
# 예상: 지원 가능? True
# Out:
# 지원 가능? True

# %% [markdown]
# ## 문제 15. 날짜 문자열 재조립 · ⭐⭐⭐ 응용
#
# `"2026-08-31"`을 `split`으로 나눈 뒤 `"2026년 8월 31일"`로 만들어 출력하세요. (`int()`로 `08`→`8`)

# %%
날짜 = "2026-08-31"

# TODO: split("-") 후 int 로 바꿔 f-string
parts = 날짜.split("-")
결과 = f"{parts[0]}년 {parts[1]}월 {parts[2]}일"
print(결과)
# 예상: 2026년 8월 31일
# Out:
# 2026년 08월 31일

# %% [markdown]
# ## 문제 16. 성적표 종합 · ⭐⭐⭐ 응용
#
# 점수에서 `영어`→95 수정, `과학`(80) 추가, **총점·평균·최고점**을 출력하세요. (`max(...values())`)

# %%
점수 = {"국어": 90, "영어": 85, "수학": 100}

# TODO
점수["영어"] = 95
# 과학 추가:
점수["과학"] = 80
총점 = sum(점수.values())
평균 = sum(점수.values()) / len(점수.values())
최고 = max(점수.values())
print("총점:", 총점, "/ 평균:", 평균, "/ 최고:", 최고)
# 예상: 총점 365 / 평균 91.25 / 최고 100
# Out:
# 총점: 365 / 평균: 91.25 / 최고: 100

# %% [markdown]
# ## 도전 1. 장바구니 영수증 + 할인 · ⭐⭐⭐⭐ 도전
#
# 장바구니 4개 항목 가격을 가격표에서 찾아 **총액**과 **10% 할인가**(총액×0.9)를 출력하세요. (인덱스 [0]~[3])

# %%
가격표 = {"우유": 2500, "빵": 3000, "계란": 5000}
장바구니 = ["우유", "빵", "우유", "계란"]

# TODO
총액 = 가격표[장바구니[0]]+가격표[장바구니[1]]+가격표[장바구니[2]]+가격표[장바구니[3]]
할인가 = 총액*0.9
print("총액:", 총액, "원")
print("할인가:", 할인가, "원")
# 예상: 총액 13000 원 / 할인가 11700.0 원
# Out:
# 총액: 13000 원
# 할인가: 11700.0 원

# %% [markdown]
# ## 도전 2. 주민번호 마스킹 · ⭐⭐⭐⭐ 도전
#
# 주민번호 **뒷자리 6개를 `*`로** 가려 `"020315-3******"`로 출력하세요. (슬라이싱 + 문자열 더하기)

# %%
id_number = "020315-3011234"

# TODO: [:8] + "******"
masked = id_number[:8] + "*"*6
print(masked)
# 예상: 020315-3******
# Out:
# 020315-3******

# %% [markdown]
# ## 제출 전 확인
#
# - ⭐ 기초 7문제는 **전부** 풀어보기 (여기서 감을 잡습니다)
# - ⭐⭐ 기본도 최대한, ⭐⭐⭐·⭐⭐⭐⭐는 **도전**해보기 (다 못 풀어도 괜찮아요)
# - 각 문제의 **예상 출력과 결과가 같은지** 확인
# - `for`·`if` 없이 풀기 (오늘 배운 것만)
#
# 막히면 강의(02-1~02-4)·실습을 다시 보거나, AI에게 **힌트만** 물어보세요(정답 통째로 X).
